# %% [markdown]
# <a href="https://colab.research.google.com/github/ebuillent13yadav/scikit-notes/blob/main/Logistic_Regression_Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1
